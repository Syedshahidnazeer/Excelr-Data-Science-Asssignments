# %%
# importing all the packages and naming them as per our convinience.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot
import warnings
warnings.filterwarnings('ignore')

# %%
#Consider only the below columns and prepare a prediction model for predicting Price.

#Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]

#Model -- model of the car
#Price  -- Offer Price in EUROs	
#Age_08_04 -- Age in months as in August 2004	
#Mfg_Month -- Manufacturing month (1-12)	
#Mfg_Year	-- Manufacturing Year
#KM -- Accumulated Kilometers on odometer
#Fuel_Type	 -- Fuel Type (Petrol, Diesel, CNG)
#HP -- Horse Power
#Met_Color	 -- Metallic Color?  (Yes=1, No=0)
#Color -- Color (Blue, Red, Grey, Silver, Black, etc.)
#Automatic	-- Automatic ( (Yes=1, No=0)
#cc -- Cylinder Volume in cubic centimeters
#Doors -- Number of doors
#Cylinders	-- Number of cylinders
#Gears -- Number of gear positions
#Quarterly_Tax -- Quarterly road tax in EUROs
#Weight -- Weight in Kilograms
#Mfr_Guarantee -- Within Manufacturer's Guarantee period  (Yes=1, No=0)
#BOVAG_Guarantee -- BOVAG (Dutch dealer network) Guarantee  (Yes=1, No=0)
#Guarantee_Period -- 	Guarantee period in months
#ABS -- Anti-Lock Brake System (Yes=1, No=0)
#Airbag_1 -- Driver_Airbag  (Yes=1, No=0)
#Airbag_2 -- Passenger Airbag  (Yes=1, No=0)
#Airco -- Airconditioning  (Yes=1, No=0)
#Automatic_airco -- Automatic Airconditioning  (Yes=1, No=0)
#Boardcomputer -- Boardcomputer  (Yes=1, No=0)
#CD_Player -- CD Player  (Yes=1, No=0)
#Central_Lock -- Central Lock  (Yes=1, No=0)
#Powered_Windows -- Powered Windows  (Yes=1, No=0)
#Power_Steering -- Power Steering  (Yes=1, No=0)
#Radio -- Radio  (Yes=1, No=0)
#Mistlamps	-- Mistlamps  (Yes=1, No=0)
#Sport_Model -- Sport Model  (Yes=1, No=0)
#ackseat_Divider -- Backseat Divider  (Yes=1, No=0)
#Metallic_Rim --Metallic Rim  (Yes=1, No=0)
#Radio_cassette -- Radio Cassette  (Yes=1, No=0)
#Tow_Bar -- Tow Bar  (Yes=1, No=0)

# %%
# Load the dataset using pandas
data=pd.read_csv('E:\MLR/ToyotaCorolla.csv',encoding='latin1')
data.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
# creating a dataframe using pandas.
df=pd.DataFrame(data)
df.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
# info function gives us the raw information of data such as any null values, data types e.t.c.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
# As the data set is so big i had to with the isnull function to see if there are any null values present in the data
df.isnull().sum().sort_values
# Out:
# <bound method Series.sort_values of Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Color               0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64>

# %%
#Consider only the below columns and prepare a prediction model for predicting Price.
#Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]
df_new=pd.concat([df.iloc[:,2:4],df.iloc[:,6:7],df.iloc[:,8:9],df.iloc[:,12:14],df.iloc[:,15:18]],axis=1)
df_new
# i have made a new dataframe as per the given condition
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
# renaming the variables for my ease of writing syntax
df_tc=df_new.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QT'},axis=1)
df_tc
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3      5   69    1025
# 1432  10845   72  19000   86  1300      3      5   69    1015
# 1433   8500   71  17016   86  1300      3      5   69    1015
# 1434   7250   70  16916   86  1300      3      5   69    1015
# 1435   6950   76      1  110  1600      5      5   19    1114
#
# [1436 rows x 9 columns]

# %%
# checking if there are any duplicated values present in the data using duplicated function
df_tc[df_tc.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 113  24950    8  13253  116  2000      5      5  234    1320

# %%
# removing the duplicate values from data and creating new data frame using drop and reset_index function
new_df=df_tc.drop_duplicates().reset_index(drop=True)
new_df
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
# we can also use the describe inbuilt function to get statistics of the data.

new_df.describe()
# Out:
#               Price          Age             KM           HP            CC  \
# count   1435.000000  1435.000000    1435.000000  1435.000000   1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986   1576.560976
# std     3608.732978    18.563312   37491.094553    14.981408    424.387533
# min     4350.000000     1.000000       1.000000    69.000000   1300.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000   1600.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000   1600.000000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.000000
#
#              Doors        Gears           QT       Weight
# count  1435.000000  1435.000000  1435.000000  1435.000000
# mean      4.032753     5.026481    87.020209  1072.287108
# std       0.952667     0.188575    40.959588    52.251882
# min       2.000000     3.000000    19.000000  1000.000000
# ...

# %%
# we use corr function to check the relationship among two variables
new_df.corr()
# Out:
#            Price       Age        KM        HP        CC     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# CC      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QT      0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#               QT    Weight
# Price   0.211508  0.575869
# Age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# CC      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
# instead of writing code to check the relation between each variables with another we can go with pair plot and see the biivariate relationship
sns.set_style(style='darkgrid')
sns.pairplot(new_df)

# %%
# make a prediction model for predicting Price.
# making the pridiction model using ordinary least square method
y=new_df["Price"]
model=smf.ols('y~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=new_df).fit()

# %%
# Coefficient parameters i.e intercept and slope
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# CC             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# Weight         16.855470
# dtype: float64

# %%
# tvalues and pvalues
model.tvalues , np.round(model.pvalues,5)
# Out:
# (Intercept    -3.875273
#  Age         -46.551876
#  KM          -16.552424
#  HP           11.209719
#  CC           -1.316436
#  Doors        -0.023012
#  Gears         3.034563
#  QT            2.944198
#  Weight       15.760663
#  dtype: float64,
#  Intercept    0.00011
#  Age          0.00000
#  KM           0.00000
#  HP           0.00000
#  CC           0.18824
#  Doors        0.98164
#  Gears        0.00245
#  QT           0.00329
#  Weight       0.00000
#  dtype: float64)

# %%
# Rsquared and Rsquared adjusted

model.rsquared , model.rsquared_adj  

# Model accuracy is 86.17% which is condidered as good.
# Out:
# (0.8625200256947, 0.8617487495415146)

# %%
model.summary()

# checking the model summary if there are any p values that are greater than 5 if so we have to remove the variable from the model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Mon, 22 May 2023   Prob (F-statistic):               0.00
# Time:                        08:16:35   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5472.5404   1412.169     -3.875      0.000   -8242.692   -2702.389
# ...

# %%
# as we have more number of variables there might be a chance of having multicollinearity issues between the x variables(independant varaibles)
# for checking collinearity between x variables we have a value called as vif(variance inflation factor) if vif>20 then we have multicollinearity issue
# Calculate VIF = 1/(1-Rsquare) for all independent variables

rsq_age=smf.ols('Age~KM+HP+CC+Doors+Gears+QT+Weight',data=new_df).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_KM=smf.ols('KM~Age+HP+CC+Doors+Gears+QT+Weight',data=new_df).fit().rsquared
vif_KM=1/(1-rsq_KM)

rsq_HP=smf.ols('HP~Age+KM+CC+Doors+Gears+QT+Weight',data=new_df).fit().rsquared
vif_HP=1/(1-rsq_HP)

rsq_CC=smf.ols('CC~Age+KM+HP+Doors+Gears+QT+Weight',data=new_df).fit().rsquared
vif_CC=1/(1-rsq_CC)

rsq_DR=smf.ols('Doors~Age+KM+HP+CC+Gears+QT+Weight',data=new_df).fit().rsquared
vif_DR=1/(1-rsq_DR)

rsq_GR=smf.ols('Gears~Age+KM+HP+CC+Doors+QT+Weight',data=new_df).fit().rsquared
vif_GR=1/(1-rsq_GR)

rsq_QT=smf.ols('QT~Age+KM+HP+CC+Doors+Gears+Weight',data=new_df).fit().rsquared
vif_QT=1/(1-rsq_QT)

rsq_WT=smf.ols('Weight~Age+KM+HP+CC+Doors+Gears+QT',data=new_df).fit().rsquared
vif_WT=1/(1-rsq_WT)

# Putting the values in Dataframe format
vif_df={'Variables':['Age','KM','HP','CC','Doors','Gears','QT','Weight'],
    'Vif':[vif_age,vif_KM,vif_HP,vif_CC,vif_DR,vif_GR,vif_QT,vif_WT]}
Vif_df=pd.DataFrame(vif_df)
Vif_df
# Out:
#   Variables       Vif
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        CC  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %%
# therefore the data has no multicollinearity issues
# say New data for prediction is
new_data=pd.DataFrame({'Age':10,"KM":50000,"HP":100,"CC":1500,"Doors":5,"Gears":6,"QT":80,"Weight":1200},index=[0])
new_data
# Out:
#    Age     KM   HP    CC  Doors  Gears  QT  Weight
# 0   10  50000  100  1500      5      6  80    1200

# %%
pred_y=model.predict(new_data)
print("price of the Toyata is=",pred_y )
# Out:
# price of the Toyata is= 0    19371.03389
# dtype: float64

# %%
# therefore the data has no multicollinearity issues
# do transformations for getting better predictions of profit as mentioned in problem statement
# we can perform Residual Analysis to remove errors and get us the best performance score
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)
# 'q' - A line is fit through the quartiles # line = '45'- to draw the 45-degree diagonal line

sm.qqplot(model.resid,line='q') 
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>6000))  

# outliar detection from above QQ plot of residuals
# Out:
# [array([109, 146, 522], dtype=int64)]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([220, 600, 959], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity

def standard_values(vals) : return (vals-vals.mean())/vals.std()

# giving input from my end as z = (x - mu)/sigma

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show() 

# plotting an integrated residual scatter plot

# %%
# using Residual Regression Plots code graphics.plot_regress_exog(model,'x',fig)
# to check the exog(independant variables) residuals when they predict y_varibles using regression plot
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Age',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'CC',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Doors',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'QT',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Weight',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
# we can see that there are errors in the x-variables while predicting y-variables
# now in order to remove this errors/outliers we are going to use cook's distance method
# According to cook'd distanec method If Cook's distance > 1, then it's an outlier
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110551e-07, 6.99854767e-04, 1.08408002e-02])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(new_df)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (80, 78.7295058225869)

# %%
# we may have many other outliers where c<0.5 to see the influence of the outlier on our prediction model we heve to see the influence plot
# Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
fig,ax=plt.subplots(figsize=(20,20))
fig=influence_plot(model,ax = ax)

# %%
# rule of thumb leverage cutoff value more than 3p/n and less than 2p/n
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=new_df.shape[1]
n=new_df.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
new_df[new_df.index.isin([80])]
# Out:
#     Price  Age     KM   HP     CC  Doors  Gears   QT  Weight
# 80  18950   25  20019  110  16000      5      5  100    1180

# %%
# Creating a new copy of data so that original dataset is not affected
toyota=new_df.copy()
toyota
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
# removing the data points which are influencers and rearranging the index values(reset_index(drop=True))
toyota=new_df.drop(new_df.index[[80]],axis=0).reset_index(drop=True)
toyota
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1429   7500   69  20544   86  1300      3      5   69    1025
# 1430  10845   72  19000   86  1300      3      5   69    1015
# 1431   8500   71  17016   86  1300      3      5   69    1015
# 1432   7250   70  16916   86  1300      3      5   69    1015
# 1433   6950   76      1  110  1600      5      5   19    1114
#
# [1434 rows x 9 columns]

# %%
# now finally fitting the model after removing the highest infuencing point
while np.max(c)>0.5 :
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota=toyota.drop(toyota.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota
else:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171204

# %%
if np.max(c)>0.5:
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota=toyota.drop(toyota.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota 
elif np.max(c)<0.5:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8882395145171204

# %%
final_model.rsquared
# Out:
# 0.8882395145171204

# %%
toyota
# we can see that we have removed 3 outliers/infuencing points from the data using cook's distance
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1426   7500   69  20544   86  1300      3      5   69    1025
# 1427  10845   72  19000   86  1300      3      5   69    1015
# 1428   8500   71  17016   86  1300      3      5   69    1015
# 1429   7250   70  16916   86  1300      3      5   69    1015
# 1430   6950   76      1  110  1600      5      5   19    1114
#
# [1431 rows x 9 columns]

# %%
# say New data for prediction is
new_data=pd.DataFrame({'Age':12,"KM":40000,"HP":80,"CC":1300,"Doors":4,"Gears":5,"QT":69,"Weight":1012},index=[0])
new_data
# Out:
#    Age     KM  HP    CC  Doors  Gears  QT  Weight
# 0   12  40000  80  1300      4      5  69    1012

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    14341.570181
# dtype: float64

# %%
# Automatic Prediction of Price with less accurcy ( privious model )
prev_model=model.predict(new_data)
prev_model
# Out:
# 0    14433.519524
# dtype: float64

# %%
# Automatic Prediction of Price with more accurcy than the previous model
pred_y=final_model.predict(new_data)
pred_y
# Out:
# 0    14341.570181
# dtype: float64

# %%
#make a table containing R^2 value for each prepared model.

r2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(r2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.883968
# 1  Final_Model  0.888240

# %%
#make a table containing R^2-adj value for each prepared model.
r2_adj={'Prep_Models':['Model','Final_Model'],'Rsquared_adj':[model.rsquared_adj,final_model.rsquared_adj]}
table=pd.DataFrame(r2_adj)
table
# Out:
#    Prep_Models  Rsquared_adj
# 0        Model      0.883316
# 1  Final_Model      0.887611
